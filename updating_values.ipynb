# %%
import pandas as pd
titanic = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/titanic.csv')
houses = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/kc_house_data.csv')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/netflix_titles.csv', sep = "|",index_col=0)
btc = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/coin_Bitcoin.csv')
countries = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/world-happiness-report-2021.csv',index_col=0)

# %%
countries.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
mapper = {"Regional indicator" : "regional_indicator", 'Ladder score': 'ladder_score'}

# %%
countries.rename(columns=mapper,inplace=True)

# %%
countries
# Out:
#     Country name  regional_indicator  ladder_score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
mapper= {'Finland':'finland'}

# %%
titanic.sex.replace('female','F')
# Out:
# 0          F
# 1       male
# 2          F
# 3       male
# 4          F
#         ...
# 1304       F
# 1305       F
# 1306    male
# 1307    male
# 1308    male
# Name: sex, Length: 1309, dtype: object

# %%
titanic['sex'].replace(['female','male'],["F","M"])
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object

# %%
titanic.sex
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object

# %%
titanic['age'].replace(["?"],[None],inplace=True)
# Out:
# /tmp/ipython-input-3086122953.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].replace(["?"],[None],inplace=True)

# %%
titanic.age.value_counts(dropna=False)
# Out:
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 60.5        1
# 74          1
# 0.4167      1
# 11.5        1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
countries.loc['Brazil':'Cambodia']
# Out:
#                               regional_indicator  ladder_score  \
# Country name
# Brazil               Latin America and Caribbean         6.330
# Mexico               Latin America and Caribbean         6.317
# Jamaica              Latin America and Caribbean         6.309
# Lithuania             Central and Eastern Europe         6.255
# Cyprus                            Western Europe         6.223
# ...                                          ...           ...
# Ukraine       Commonwealth of Independent States         4.875
# Iraq                Middle East and North Africa         4.854
# Gabon                         Sub-Saharan Africa         4.852
# Burkina Faso                  Sub-Saharan Africa         4.834
# Cambodia                          Southeast Asia         4.830
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
# ...

# %%
countries.set_index('Country name',inplace=True)

# %%
countries.loc['Brazil', ['Ladder score','Healthy life expectancy'] ]
# Out:
# Ladder score                 6.33
# Healthy life expectancy    66.601
# Name: Brazil, dtype: object

# %%
countries.loc[['Denmark','Sweden','Norway'],['Regional indicator']]
# Out:
#              Regional indicator
# Country name
# Denmark          Western Europe
# Sweden           Western Europe
# Norway           Western Europe

# %%
countries.head(10)
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Finland              Western Europe         7.842
# Denmark              Western Europe         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway               Western Europe         7.392
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.loc['Finland']="LOL"
# Out:
# /tmp/ipython-input-2989409208.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'LOL' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   countries.loc['Finland']="LOL"
# /tmp/ipython-input-2989409208.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'LOL' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   countries.loc['Finland']="LOL"
# /tmp/ipython-input-2989409208.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'LOL' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   countries.loc['Finland']="LOL"
# ...

# %%
countries.loc['Finland']
# Out:
# Regional indicator                            LOL
# Ladder score                                  LOL
# Standard error of ladder score                LOL
# upperwhisker                                  LOL
# lowerwhisker                                  LOL
# Logged GDP per capita                         LOL
# Social support                                LOL
# Healthy life expectancy                       LOL
# Freedom to make life choices                  LOL
# Generosity                                    LOL
# Perceptions of corruption                     LOL
# Ladder score in Dystopia                      LOL
# Explained by: Log GDP per capita              LOL
# Explained by: Social support                  LOL
# Explained by: Healthy life expectancy         LOL
# Explained by: Freedom to make life choices    LOL
# Explained by: Generosity                      LOL
# Explained by: Perceptions of corruption       LOL
# Dystopia + residual                           LOL
# ...

# %%
houses[houses['bedrooms'] >= 10]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# ...

# %%
many_bedrooms = houses['bedrooms'] >= 10

# %%
many_bedrooms
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
houses.loc[many_bedrooms]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# ...

# %%
houses.loc[many_bedrooms,["bedrooms"]] = "too many"
# Out:
# /tmp/ipython-input-2940156524.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'too many' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   houses.loc[many_bedrooms,["bedrooms"]] = "too many"

# %%
high_quality = houses['grade'] > 10

# %%
great_view = houses["view"] == 4

# %%
our_condition= high_quality & great_view

# %%
houses['luxury_level'] = "normal"

# %%
houses
# Out:
#                id             date     price bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900.0        3       1.00         1180
# 1      6414100192  20141209T000000  538000.0        3       2.25         2570
# 2      5631500400  20150225T000000  180000.0        2       1.00          770
# 3      2487200875  20141209T000000  604000.0        4       3.00         1960
# 4      1954400510  20150218T000000  510000.0        3       2.00         1680
# ...           ...              ...       ...      ...        ...          ...
# 21608   263000018  20140521T000000  360000.0        3       2.50         1530
# 21609  6600060120  20150223T000000  400000.0        4       2.50         2310
# 21610  1523300141  20140623T000000  402101.0        2       0.75         1020
# 21611   291310100  20150116T000000  400000.0        3       2.50         1600
# 21612  1523300157  20141015T000000  325000.0        2       0.75         1020
#
# ...

# %%
houses.loc[our_condition,"luxury_level"] = "luxurious"

# %%
houses.loc[our_condition]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 540     622049114  20150218T000000  2125000.0        3       2.50
# 1164   1247600105  20141020T000000  5110800.0        5       5.25
# 1315   7558700030  20150413T000000  5300000.0        6       6.00
# 1448   8907500070  20150413T000000  5350000.0        5       5.00
# 2085   8106100105  20141114T000000  3850000.0        4       4.25
# 2444   7524900003  20141210T000000  3278000.0        2       1.75
# 2626   7738500731  20140815T000000  4500000.0        5       5.50
# 2713   7851980260  20140730T000000  1110000.0        5       3.50
# 3157   1827200265  20140911T000000  1899000.0        2       2.75
# 3586   9272200090  20150204T000000  1598890.0        4       4.50
# 4013    724069059  20140509T000000  2400000.0        3       2.25
# 4190   2303900090  20140729T000000  2880500.0        4       2.50
# 4406   3505100756  20141106T000000  2050000.0        4       3.00
# ...

# %%
df.set_index("show_id", inplace=True)

# %%
df.loc["s2202", "director"] = "Greg Whiteley"

# %%
df.loc[["s2881", "s3601"], "duration"] = "Updated Duration"

# %%
df.rename(columns={"release_year": "release_yr"}, inplace=True)

# %%
df.rename(index={df[df["title"] == "Evil"].index[0] : "s6666"}, inplace=True)

# %%
df[df["title"] == "Evil"]
# Out:
#             type title director  \
# show_id
# s6666    TV Show  Evil      NaN
#
#                                                       cast        country  \
# show_id
# s6666    Katja Herbers, Mike Colter, Aasif Mandvi, Mich...  United States
#
#               date_added  release_yr rating  duration  listed_in  \
# show_id
# s6666    October 1, 2020        2019  TV-14  1 Season  TV Dramas
#
#                                                description
# show_id
# s6666    A forensic psychologist partners with a Cathol...

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...
