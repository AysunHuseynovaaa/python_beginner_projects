# %%
import pandas as pd
titanic = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/titanic.csv')
houses = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/kc_house_data.csv')
netflix = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/netflix_titles.csv', sep = "|",index_col=0)
btc = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/coin_Bitcoin.csv')
countries = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/world-happiness-report-2021.csv')

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses.insert(0,'county','King County')

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
houses['sales_price']=houses["price"]

# %%
houses.insert(3,'num_bedrooms',houses["bedrooms"])

# %%
 titanic.drop(labels='species',axis=1,inplace=True) # This line caused an error because 'species' column does not exist.

# %%
titanic['species'] = 'Human'
display(titanic.head())
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest species
# ...

# %%
titanic['parch']
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: parch, Length: 1309, dtype: int64

# %%
titanic['relatives']=titanic['parch']+titanic['sibsp']

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.insert(2,'relatives2',titanic['parch']+titanic['sibsp'])

# %%
titanic
# Out:
#       pclass  survived  relatives2  \
# 0          1         1           0
# 1          1         1           3
# 2          1         0           3
# 3          1         0           3
# 4          1         0           3
# ...      ...       ...         ...
# 1304       3         0           1
# 1305       3         0           1
# 1306       3         0           0
# 1307       3         0           0
# 1308       3         0           0
#
#                                                  name     sex     age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female      29      0
# 1                      Allison, Master. Hudson Trevor    male  0.9167      1
# 2                        Allison, Miss. Helen Loraine  female       2      1
# 3                Allison, Mr. Hudson Joshua Creighton    male      30      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25      1
# ...

# %%
titanic.sort_values(by='relatives2',ascending=False)
# Out:
#       pclass  survived  relatives2  \
# 1180       3         0          10
# 1179       3         0          10
# 1170       3         0          10
# 1171       3         0          10
# 1172       3         0          10
# ...      ...       ...         ...
# 600        3         0           0
# 604        3         1           0
# 605        3         1           0
# 606        3         1           0
# 580        2         1           0
#
#                                               name     sex   age  sibsp  \
# 1180                Sage, Mrs. John (Annie Bullen)  female     ?      1
# 1179                         Sage, Mr. John George    male     ?      1
# 1170                    Sage, Master. Thomas Henry    male     ?      8
# 1171                   Sage, Master. William Henry    male  14.5      8
# 1172                               Sage, Miss. Ada  female     ?      8
# ...                                            ...     ...   ...    ...
# ...

# %%
survived=titanic['survived']==1

# %%
titanic[survived].sort_values(by='relatives2',ascending=False)
# Out:
#       pclass  survived  relatives2  \
# 641        3         1           6
# 643        3         1           6
# 646        3         1           6
# 625        3         1           6
# 112        1         1           5
# ...      ...       ...         ...
# 1236       3         1           0
# 1233       3         1           0
# 1232       3         1           0
# 1228       3         1           0
# 1223       3         1           0
#
#                                                    name     sex age  sibsp  \
# 641                   Asplund, Master. Edvin Rojj Felix    male   3      4
# 643                      Asplund, Miss. Lillian Gertrud  female   5      4
# 646   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38      1
# 625                     Andersson, Miss. Erna Alexandra  female  17      4
# 112                          Fortune, Miss. Ethel Flora  female  28      3
# ...                                                 ...     ...  ..    ...
# ...

# %%
titanic[survived].nlargest(n=5,columns='relatives2')
# Out:
#      pclass  survived  relatives2  \
# 625       3         1           6
# 641       3         1           6
# 643       3         1           6
# 646       3         1           6
# 111       1         1           5
#
#                                                   name     sex age  sibsp  \
# 625                    Andersson, Miss. Erna Alexandra  female  17      4
# 641                  Asplund, Master. Edvin Rojj Felix    male   3      4
# 643                     Asplund, Miss. Lillian Gertrud  female   5      4
# 646  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38      1
# 111                     Fortune, Miss. Alice Elizabeth  female  24      3
#
#      parch   ticket     fare        cabin embarked boat body  \
# 625      2  3101281    7.925            ?        S    D    ?
# 641      2   347077  31.3875            ?        S   15    ?
# 643      2   347077  31.3875            ?        S   15    ?
# 646      5   347077  31.3875            ?        S   15    ?
# ...

# %%
soloTravelers=titanic['relatives2']==0

# %%
titanic[soloTravelers]
# Out:
#       pclass  survived  relatives2                           name     sex  \
# 0          1         1           0  Allen, Miss. Elisabeth Walton  female
# 5          1         1           0            Anderson, Mr. Harry    male
# 7          1         0           0         Andrews, Mr. Thomas Jr    male
# 9          1         0           0        Artagaveytia, Mr. Ramon    male
# 12         1         1           0  Aubart, Mme. Leontine Pauline  female
# ...      ...       ...         ...                            ...     ...
# 1302       3         0           0              Yousif, Mr. Wazli    male
# 1303       3         0           0          Yousseff, Mr. Gerious    male
# 1306       3         0           0      Zakarian, Mr. Mapriededer    male
# 1307       3         0           0            Zakarian, Mr. Ortin    male
# 1308       3         0           0             Zimmerman, Mr. Leo    male
#
#        age  sibsp  parch    ticket      fare cabin embarked boat body  \
# ...

# %%
titanic[soloTravelers].pclass.value_counts()
# Out:
# pclass
# 3    472
# 1    160
# 2    158
# Name: count, dtype: int64

# %%
titanic[soloTravelers].sex.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
houses['price'] / houses['sqft_living']
# Out:
# 0        188.050847
# 1        209.338521
# 2        233.766234
# 3        308.163265
# 4        303.571429
#             ...
# 21608    235.294118
# 21609    173.160173
# 21610    394.216667
# 21611    250.000000
# 21612    318.627451
# Length: 21613, dtype: float64

# %%
houses['price_per_sqft']=houses['price'] / houses['sqft_living']

# %%
houses.nlargest(n=5,columns='price_per_sqft')
# Out:
#             county          id             date  num_bedrooms      price  \
# 19336  King County  6021500970  20150407T000000             2   874950.0
# 4013   King County   724069059  20140509T000000             3  2400000.0
# 10446  King County  1118000320  20150508T000000             4  3400000.0
# 8623   King County  6303400395  20150130T000000             1   325000.0
# 9314   King County  4389200610  20141201T000000             2   903000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# 19336         2       1.00         1080      4000     1.0  ...              0
# 4013          3       2.25         3000     11665     1.5  ...              0
# 10446         4       4.00         4260     11765     2.0  ...            980
# 8623          1       0.75          410      8636     1.0  ...              0
# 9314          2       1.50         1140      7800     1.0  ...              0
#
# ...

# %%
houses.sort_values(by='price_per_sqft',ascending=False).head(20).zipcode.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='zipcode'>

# %%
btc.set_index('Date',inplace=True)

# %%
btc['change'] = btc['Close']-btc['Open']

# %%
btc.sort_values(by='change',ascending=False).head(20)
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2021-02-08 23:59:59  2843  Bitcoin    BTC  46203.931437  38076.322807
# 2021-04-26 23:59:59  2920  Bitcoin    BTC  54288.002155  48852.796843
# 2021-03-01 23:59:59  2864  Bitcoin    BTC  49784.015290  45115.093115
# 2021-02-19 23:59:59  2854  Bitcoin    BTC  56113.650547  50937.275722
# 2021-04-30 23:59:59  2924  Bitcoin    BTC  57900.719988  53129.600877
# 2021-05-05 23:59:59  2929  Bitcoin    BTC  57911.363597  52969.055363
# 2021-05-20 23:59:59  2944  Bitcoin    BTC  42462.984986  35050.615825
# 2021-05-24 23:59:59  2948  Bitcoin    BTC  39835.139830  34551.080550
# 2021-06-09 23:59:59  2964  Bitcoin    BTC  37537.371150  32475.866031
# 2021-03-13 23:59:59  2876  Bitcoin    BTC  61683.864014  56217.972382
# 2017-12-07 23:59:59  1684  Bitcoin    BTC  17899.699219  14057.299805
# 2021-04-13 23:59:59  2907  Bitcoin    BTC  63742.283337  59869.956293
# ...

# %%
btc['delta'] = btc['High'] - btc['Low']

# %%
btc.sort_values(by='delta',ascending=False).head(20)
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2021-05-19 23:59:59  2943  Bitcoin    BTC  43546.116485  30681.496912
# 2021-02-23 23:59:59  2858  Bitcoin    BTC  54204.929756  45290.590268
# 2021-05-12 23:59:59  2936  Bitcoin    BTC  57939.362415  49150.533875
# 2021-02-22 23:59:59  2857  Bitcoin    BTC  57533.389325  48967.565188
# 2021-05-21 23:59:59  2945  Bitcoin    BTC  42172.173616  33616.453884
# 2021-04-18 23:59:59  2912  Bitcoin    BTC  61057.456509  52829.535926
# 2021-02-08 23:59:59  2843  Bitcoin    BTC  46203.931437  38076.322807
# 2021-01-11 23:59:59  2815  Bitcoin    BTC  38346.529503  30549.598769
# 2021-05-20 23:59:59  2944  Bitcoin    BTC  42462.984986  35050.615825
# 2021-05-23 23:59:59  2947  Bitcoin    BTC  38289.218120  31227.339433
# 2021-01-29 23:59:59  2833  Bitcoin    BTC  38406.260965  32064.814187
# 2021-03-18 23:59:59  2881  Bitcoin    BTC  60116.249644  54253.580005
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/JoeBidenTweets.csv", index_col="id")

# %%
df = df.drop(columns=["url"])

# %%
df = df.drop(361388562)

# %%
df["user"] = "Joe Biden"

# %%
df["ratio"] = df["replies"] / df["retweets"]

# %%
top_10_ratio = df.sort_values("ratio", ascending=False).head(10)

# %%
df["interaction"] = df["replies"] + df["retweets"] + df["quotes"] + df["likes"]

# %%
top_8_interaction = df.sort_values("interaction", ascending=False).head(8)

# %%
df
# Out:
#                             timestamp  \
# id
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# 189343279140184065   2012-04-09 13:25
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                  tweet  \
# id
# 543984392            Iowans, there's a good chance there's a Biden ...
# 189287227321356289   We're excited to announce that @JoeBiden is be...
# 189287350034104320   Campaign staff will run this account to keep y...
# 189339650610036736   News for you this morning: VP Biden will speak...
# 189343279140184065   In NH on 4/12, the Vice President will give hi...
# ...
